# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\mohit khangar\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\mohit khangar\anaconda3\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\mohit khangar\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\mohit khangar\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\mohit khangar\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
features = [
    [150, 0],  # Apple
    [170, 0],  # Apple
    [130, 1],  # Orange
    [120, 1],  # Orange
]

# %%
labels = ["apple", "apple", "orange", "orange"]

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(features, labels)

# %%
prediction = clf.predict([[150,1]])

# %%
print(f"The Fruit is {prediction[0]}")
# Out:
# The Fruit is orange
